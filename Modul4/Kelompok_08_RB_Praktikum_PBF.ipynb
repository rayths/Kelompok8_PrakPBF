# %% [markdown]
# # Tugas Kelompok Modul 4
#
# Nama Anggota Kelompok 8:
#
# Arafi Ramadhan Maulana - 122450004\
# Dwi Ratna Anggraeni - 122450008\
# Raid Muhammad Naufal - 122450027\
# Rayan Koemi Karuby - 122450038\
# M. Deriansyah Okutra - 122450101

# %% [markdown]
# ## Correlation Matrix Generator

# %% [markdown]
# ### Import Library

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Fungsi Correlation Matrix Generator

# %%
def correlation_matrix_generator():
  def correlation_plot(data):
    df = pd.DataFrame(data)
    corr_matrix = df.corr()
    plt.figure(figsize=(10, 10))
    sns.heatmap(corr_matrix, annot=True)
    plt.show()

  return correlation_plot

# %% [markdown]
# ## Import Dataset
#
# https://drive.google.com/file/d/1_LJndesVIe7JvviZa9bS3UkJDsNM3xNs/view?usp=sharing

# %%
data = pd.read_csv("diabetes.csv")

# %% [markdown]
# ### Dataset

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 747           10      101             76             48      180  32.9
# 748            2      122             70             27        0  36.8
# 749            5      121             72             23      112  26.2
# 750            1      126             60              0        0  30.1
# 751            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50     Case
# ...

# %% [markdown]
# ### Preprocessing Data

# %%
data['Outcome'] = data['Outcome'].replace({'Case': 1, 'Control': 0})

# %% [markdown]
# ### Penggunaan Correlation Matrix Generator

# %%
correlation = correlation_matrix_generator()
correlation(data)
